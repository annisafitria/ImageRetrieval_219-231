# %% [markdown]
# <a href="https://colab.research.google.com/github/annisafitria/ImageRetrieval_219-231/blob/main/Tugas_Besar_Image_Retrieval_201810370311219_201810370311231.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Build Model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd "/content/drive/MyDrive/Tugas/Semester 7"
# Out:
# /content/drive/MyDrive/Tugas/Semester 7

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import offsetbox
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from sklearn import manifold

class CV_plot_utils:
  # Plot image
  def plot_img(img, range=[0, 255]):
      plt.imshow(img, vmin=range[0], vmax=range[1])
      plt.xlabel("xpixels")
      plt.ylabel("ypixels")
      plt.tight_layout()
      plt.show()
      plt.close()

  # Plots images in 2 rows: top row is query, bottom row is answer
  def plot_query_retrieval(img_query, imgs_retrieval, outFile):
      n_retrieval = len(imgs_retrieval)
      fig = plt.figure(figsize=(2*n_retrieval, 4))
      fig.suptitle("Image Retrieval (k={})".format(n_retrieval), fontsize=25)

      # Plot query image
      ax = plt.subplot(2, n_retrieval, 0 + 1)
      plt.imshow(img_query)
      ax.get_xaxis().set_visible(False)
      ax.get_yaxis().set_visible(False)
      for axis in ['top', 'bottom', 'left', 'right']:
          ax.spines[axis].set_linewidth(4)  # increase border thickness
          ax.spines[axis].set_color('black')  # set to black
      ax.set_title("query",  fontsize=14)  # set subplot title

      # Plot retrieval images
      for i, img in enumerate(imgs_retrieval):
          ax = plt.subplot(2, n_retrieval, n_retrieval + i + 1)
          plt.imshow(img)
          ax.get_xaxis().set_visible(False)
          ax.get_yaxis().set_visible(False)
          for axis in ['top', 'bottom', 'left', 'right']:
              ax.spines[axis].set_linewidth(1)  # set border thickness
              ax.spines[axis].set_color('black')  # set to black
          ax.set_title("Rank #%d" % (i+1), fontsize=14)  # set subplot title

      if outFile is None:
          plt.show()
      else:
          plt.savefig(outFile, bbox_inches='tight')
      plt.close()

  # Plot t-SNE of images
  def plot_tsne(X, imgs, outFile):

      def imscatter(x, y, images, ax=None, zoom=1.0):
          if ax is None:
              ax = plt.gca()
          x, y = np.atleast_1d(x, y)
          artists = []
          for x0, y0, img0 in zip(x, y, images):
              im = OffsetImage(img0, zoom=zoom)
              ab = AnnotationBbox(im, (x0, y0), xycoords='data', frameon=True)
              artists.append(ax.add_artist(ab))
          ax.update_datalim(np.column_stack([x, y]))
          ax.autoscale()
          return artists

      def plot_embedding(X, imgs, title=None):
          x_min, x_max = np.min(X, 0), np.max(X, 0)
          X = (X - x_min) / (x_max - x_min)

          plt.figure()
          ax = plt.subplot(111)
          for i in range(X.shape[0]):
              plt.text(X[i, 0], X[i, 1], ".", fontdict={'weight': 'bold', 'size': 9})
          if hasattr(offsetbox, 'AnnotationBbox'):
              imscatter(X[:,0], X[:,1], imgs, zoom=0.3, ax=ax)

          plt.xticks([]), plt.yticks([])
          if title is not None:
              plt.title(title, fontsize=18)

      tsne = manifold.TSNE(n_components=2, init='pca', random_state=0)
      X_tsne = tsne.fit_transform(X)
      plot_embedding(X_tsne, imgs, "t-SNE embeddings")
      if outFile is None:
          plt.show()
      else:
          plt.savefig(outFile, bbox_inches='tight')
      plt.close()

  # Plot image reconstructions
  def plot_reconstructions(imgs, imgs_reconstruct, outFile,
                          range_imgs=[0, 255],
                          range_imgs_reconstruct=[0, 1]):
      # Create plot to save
      assert len(imgs) == len(imgs_reconstruct)
      fig = plt.figure(figsize=(20, 4))
      fig.suptitle("Image Reconstructions", fontsize=35)
      n = min(len(imgs), 10)
      for i in range(n):

          # Plot original image
          ax = plt.subplot(2, n, i + 1)
          plt.imshow(imgs[i],
                    vmin=range_imgs[0],
                    vmax=range_imgs[1])
          ax.get_xaxis().set_visible(False)
          ax.get_yaxis().set_visible(False)

          # Plot reconstructed image
          ax = plt.subplot(2, n, n + i + 1)
          plt.imshow(imgs_reconstruct[i],
                    vmin=range_imgs_reconstruct[0],
                    vmax=range_imgs_reconstruct[1])
          ax.get_xaxis().set_visible(False)
          ax.get_yaxis().set_visible(False)

      if outFile is None:
          plt.show()
      else:
          plt.savefig(outFile, bbox_inches='tight')
      plt.close()

# %%
import os
import skimage.io
from multiprocessing import Pool

class CV_IO_utils:
  # Read image
  def read_img(filePath):
      return skimage.io.imread(filePath, as_gray=False)

  # Read images with common extensions from a directory
  def read_imgs_dir(dirPath, extensions, parallel=True):
      args = [os.path.join(dirPath, filename)
              for filename in os.listdir(dirPath)
              if any(filename.lower().endswith(ext) for ext in extensions)]
      if parallel:
          pool = Pool()
          imgs = pool.map(CV_IO_utils.read_img, args)
          pool.close()
          pool.join()
      else:
          imgs = [read_img(arg) for arg in args]
      return imgs

  # Save image to file
  def save_img(filePath, img):
      skimage.io.imsave(filePath, img)

# %%
from multiprocessing import Pool
from skimage.transform import resize

# Apply transformations to multiple images
class CV_transform_utils:
    
  def apply_transformer(imgs, transformer, parallel=True):
      if parallel:
          pool = Pool()
          imgs_transform = pool.map(transformer, [img for img in imgs])
          pool.close()
          pool.join()
      else:
          imgs_transform = [transformer(img) for img in imgs]
      return imgs_transform

  # Normalize image data [0, 255] -> [0.0, 1.0]
  def normalize_img(img):
      return img / 255.

  # Resize image
  def resize_img(img, shape_resized):
      img_resized = resize(img, shape_resized,
                          anti_aliasing=True,
                          preserve_range=True)
      assert img_resized.shape == shape_resized
      return img_resized

  # Flatten image
  def flatten_img(img):
      return img.flatten("C")

# %%
import random
import numpy as np

class utils:
    # Get split indices
  def split(fracs, N, seed):
      fracs = [round(frac, 2) for frac in fracs]
      if sum(fracs) != 1.00:
          raise Exception("fracs do not sum to one!")

      # Shuffle ordered indices
      indices = list(range(N))
      random.Random(seed).shuffle(indices)
      indices = np.array(indices, dtype=int)

      # Get numbers per group
      n_fracs = []
      for i in range(len(fracs) - 1):
          n_fracs.append(int(max(fracs[i] * N, 0)))
      n_fracs.append(int(max(N - sum(n_fracs), 0)))

      if sum(n_fracs) != N:
          raise Exception("n_fracs do not sum to N!")

      # Sample indices
      n_selected = 0
      indices_fracs = []
      for n_frac in n_fracs:
          indices_frac = indices[n_selected:n_selected + n_frac]
          indices_fracs.append(indices_frac)
          n_selected += n_frac

      # Check no intersections
      for a, indices_frac_A in enumerate(indices_fracs):
          for b, indices_frac_B in enumerate(indices_fracs):
              if a == b:
                  continue
              if utils.is_intersect(indices_frac_A, indices_frac_B):
                  raise Exception("there are intersections!")

      return indices_fracs

  # Is there intersection?
  def is_intersect(arr1, arr2):
      n_intersect = len(np.intersect1d(arr1, arr2))
      if n_intersect == 0: return False
      else: return True

# %%
import os
import numpy as np
import tensorflow as tf
from sklearn.neighbors import NearestNeighbors
import copy
import sklearn.metrics as metric
from statistics import mean
import re

# %%
correct = 0
wrong = 0
loss_ = []
acc_ = []
ground_truth = []
retrieval_labels = []
precision = []
recall = []
acc_transfer = []
loss_transfer = []
prec_transfer = []
rec_transfer = []

retrieval_label=os.listdir(r"/content/drive/MyDrive/Tugas/Semester 7/Data (1)/train")
truth_label=os.listdir(r"/content/drive/MyDrive/Tugas/Semester 7/Data (1)/test")

# %%
# Apply transformations to all images
class ImageTransformer(object):

    def __init__(self, shape_resize):
        self.shape_resize = shape_resize

    def __call__(self, img):
        img_transformed = CV_transform_utils.resize_img(img, self.shape_resize)
        img_transformed = CV_transform_utils.normalize_img(img_transformed)
        return img_transformed

transfer = ['InceptionResNetV2', 'GoogleNet', 'Xception', 'VGG16', 'VGG19', 
            'ResNet50', 'ResNet101', 'ResNet152', 'ResNet50V2', 'ResNet101V2', 
            'ResNet152V2', 'InceptionV3', 'DenseNet121', 'DenseNet169', 
            'DenseNet201', 'NASNetMobile', 'NASNetLarge', 'EfficientNetB0', 
            'MobileNet', 'MobileNetV2','EfficientNetB1', 'EfficientNetB2', 
            'EfficientNetB3', 'EfficientNetB4', 'EfficientNetB5', 
            'EfficientNetB6', 'EfficientNetB7']

# Run mode: (autoencoder -> simpleAE, convAE) or (transfer learning -> vgg19)
modelName = "vgg19"  # try: "simpleAE", "convAE", "vgg19"
trainModel = True
parallel = True  # use multicore processing

# Make paths
dataTrainDir = "/content/drive/MyDrive/Tugas/Semester 7/Data (1)/train"
dataTestDir = "/content/drive/MyDrive/Tugas/Semester 7/Data (1)/test"
outDir = os.path.join(os.getcwd(), "outputImages", modelName)
if not os.path.exists(outDir):
    os.makedirs(outDir)

# Read images
extensions = [".png"]
print("Reading train images from '{}'...".format(dataTrainDir))
imgs_train = CV_IO_utils.read_imgs_dir(dataTrainDir, extensions, parallel=parallel)
print("Reading test images from '{}'...".format(dataTestDir))
imgs_test = CV_IO_utils.read_imgs_dir(dataTestDir, extensions, parallel=parallel)
shape_img = imgs_train[0].shape
print("Image shape = {}".format(shape_img))

print("Loading VGG19 pre-trained model...")
model = tf.keras.applications.InceptionResNetV2(weights='imagenet', include_top=False,
                                            input_shape=(288, 409, 3))
model.summary()

shape_img_resize = tuple([int(x) for x in model.input.shape[1:]])
input_shape_model = tuple([int(x) for x in model.input.shape[1:]])
output_shape_model = tuple([int(x) for x in model.output.shape[1:]])
n_epochs = None
# Build models

# Print some model info
print("input_shape_model = {}".format(input_shape_model))
print("output_shape_model = {}".format(output_shape_model))

transformer = ImageTransformer(shape_img_resize)
print("Applying image transformer to training images...")
imgs_train_transformed = CV_transform_utils.apply_transformer(imgs_train, transformer, parallel=parallel)
print("Applying image transformer to test images...")
imgs_test_transformed = CV_transform_utils.apply_transformer(imgs_test, transformer, parallel=parallel)

# Convert images to numpy array
X_train = np.array(imgs_train_transformed).reshape((-1,) + input_shape_model)
X_test = np.array(imgs_test_transformed).reshape((-1,) + input_shape_model)
print(" -> X_train.shape = {}".format(X_train.shape))
print(" -> X_test.shape = {}".format(X_test.shape))

# Create embeddings using model
print("Inferencing embeddings using pre-trained model...")
E_train = model.predict(X_train)
E_train_flatten = E_train.reshape((-1, np.prod(output_shape_model)))
E_test = model.predict(X_test)
E_test_flatten = E_test.reshape((-1, np.prod(output_shape_model)))
print(" -> E_train.shape = {}".format(E_train.shape))
print(" -> E_test.shape = {}".format(E_test.shape))
print(" -> E_train_flatten.shape = {}".format(E_train_flatten.shape))
print(" -> E_test_flatten.shape = {}".format(E_test_flatten.shape))

# Fit kNN model on training images
print("Fitting k-nearest-neighbour model on training images...")
knn = NearestNeighbors(n_neighbors=10, metric="cosine")
knn.fit(E_train_flatten)

# Perform image retrieval on test images
print("Performing image retrieval on test images...")
for i, emb_flatten in enumerate(E_test_flatten):
    _, indices = knn.kneighbors([emb_flatten]) # find k nearest train neighbours
    img_query = imgs_test[i] # query image
    imgs_retrieval = [imgs_train[idx] for idx in indices.flatten()] # retrieval images
    for x in indices.flatten():
      if truth_label[i][:3] in retrieval_label[x]:
        correct = correct + 1
      else:
        wrong = wrong + 1
    loss_.append((wrong/5))
    acc_.append((correct/5))
    correct = 0
    wrong = 0

    # Precision Recall
    for x in indices.flatten():
      ground_truth.append(re.split("(\d.*)", truth_label[i])[0])
      retrieval_labels.append(re.split("(\d.*)", retrieval_label[x])[0])
    
    recall.append(metric.recall_score(ground_truth, retrieval_labels, average='weighted'))
    precision.append(metric.precision_score(ground_truth, retrieval_labels, average='weighted'))

    ground_truth.clear()
    retrieval_labels.clear()

    outFile = os.path.join(outDir, "{}_retrieval_{}.png".format(modelName, i))
    CV_plot_utils.plot_query_retrieval(img_query, imgs_retrieval, outFile)

print("retrieval accuracy: {}".format(mean(acc_)))
print("retrieval loss: {}".format(mean(loss_)))
print("retrieval precision: {}".format(mean(precision)))
print("retrieval recall: {}".format(mean(recall)))
# Out:
# Reading train images from '/content/drive/MyDrive/Tugas/Semester 7/Data (1)/train'...
# Reading test images from '/content/drive/MyDrive/Tugas/Semester 7/Data (1)/test'...
# Image shape = (288, 409, 4)
# Loading VGG19 pre-trained model...
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 288, 409, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 143, 204, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 143, 204, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 143, 204, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 141, 202, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 141, 202, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 141, 202, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 141, 202, 64  18432       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 141, 202, 64  192        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 141, 202, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 70, 100, 64)  0           ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 70, 100, 80)  5120        ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 70, 100, 80)  240        ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 70, 100, 80)  0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 68, 98, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 68, 98, 192)  576        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 68, 98, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 33, 48, 192)  0          ['activation_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 33, 48, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 33, 48, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 33, 48, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 33, 48, 48)   9216        ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 33, 48, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 33, 48, 48)  144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 33, 48, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 33, 48, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 33, 48, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 33, 48, 192)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  conv2d_5 (Conv2D)              (None, 33, 48, 96)   18432       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 33, 48, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 33, 48, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 33, 48, 64)   12288       ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 33, 48, 96)  288         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 33, 48, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 33, 48, 96)  288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 33, 48, 64)  192         ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 33, 48, 96)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 33, 48, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 33, 48, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 33, 48, 64)   0           ['batch_normalization_11[0][0]']
#
#  mixed_5b (Concatenate)         (None, 33, 48, 320)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 33, 48, 32)   10240       ['mixed_5b[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 33, 48, 32)  96          ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 33, 48, 32)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 33, 48, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 33, 48, 48)   13824       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 33, 48, 32)  96          ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 33, 48, 48)  144         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 33, 48, 32)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 33, 48, 48)   0           ['batch_normalization_16[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 33, 48, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 33, 48, 32)   9216        ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 33, 48, 64)   27648       ['activation_16[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 33, 48, 32)  96          ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 33, 48, 32)  96          ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 33, 48, 64)  192         ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 33, 48, 32)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 33, 48, 32)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 33, 48, 64)   0           ['batch_normalization_17[0][0]']
#
#  block35_1_mixed (Concatenate)  (None, 33, 48, 128)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]']
#
#  block35_1_conv (Conv2D)        (None, 33, 48, 320)  41280       ['block35_1_mixed[0][0]']
#
#  block35_1 (Lambda)             (None, 33, 48, 320)  0           ['mixed_5b[0][0]',
#                                                                   'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)      (None, 33, 48, 320)  0           ['block35_1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 33, 48, 32)   10240       ['block35_1_ac[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 33, 48, 32)  96          ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 33, 48, 32)   0           ['batch_normalization_21[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 33, 48, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 33, 48, 48)   13824       ['activation_21[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 33, 48, 32)  96          ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, 33, 48, 48)  144         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 33, 48, 32)   0           ['batch_normalization_19[0][0]']
#
#  activation_22 (Activation)     (None, 33, 48, 48)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 33, 48, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 33, 48, 32)   9216        ['activation_19[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 33, 48, 64)   27648       ['activation_22[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 33, 48, 32)  96          ['conv2d_18[0][0]']
#  ormalization)
#
#  batch_normalization_20 (BatchN  (None, 33, 48, 32)  96          ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 33, 48, 64)  192         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 33, 48, 32)   0           ['batch_normalization_18[0][0]']
#
#  activation_20 (Activation)     (None, 33, 48, 32)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 33, 48, 64)   0           ['batch_normalization_23[0][0]']
#
#  block35_2_mixed (Concatenate)  (None, 33, 48, 128)  0           ['activation_18[0][0]',
#                                                                   'activation_20[0][0]',
#                                                                   'activation_23[0][0]']
#
#  block35_2_conv (Conv2D)        (None, 33, 48, 320)  41280       ['block35_2_mixed[0][0]']
#
#  block35_2 (Lambda)             (None, 33, 48, 320)  0           ['block35_1_ac[0][0]',
#                                                                   'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)      (None, 33, 48, 320)  0           ['block35_2[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 33, 48, 32)   10240       ['block35_2_ac[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 33, 48, 32)  96          ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 33, 48, 32)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 33, 48, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 33, 48, 48)   13824       ['activation_27[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 33, 48, 32)  96          ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_28 (BatchN  (None, 33, 48, 48)  144         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 33, 48, 32)   0           ['batch_normalization_25[0][0]']
#
#  activation_28 (Activation)     (None, 33, 48, 48)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 33, 48, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 33, 48, 32)   9216        ['activation_25[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 33, 48, 64)   27648       ['activation_28[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 33, 48, 32)  96          ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_26 (BatchN  (None, 33, 48, 32)  96          ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 33, 48, 64)  192         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 33, 48, 32)   0           ['batch_normalization_24[0][0]']
#
#  activation_26 (Activation)     (None, 33, 48, 32)   0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 33, 48, 64)   0           ['batch_normalization_29[0][0]']
#
#  block35_3_mixed (Concatenate)  (None, 33, 48, 128)  0           ['activation_24[0][0]',
#                                                                   'activation_26[0][0]',
#                                                                   'activation_29[0][0]']
#
#  block35_3_conv (Conv2D)        (None, 33, 48, 320)  41280       ['block35_3_mixed[0][0]']
#
#  block35_3 (Lambda)             (None, 33, 48, 320)  0           ['block35_2_ac[0][0]',
#                                                                   'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)      (None, 33, 48, 320)  0           ['block35_3[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 33, 48, 32)   10240       ['block35_3_ac[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 33, 48, 32)  96          ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 33, 48, 32)   0           ['batch_normalization_33[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 33, 48, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 33, 48, 48)   13824       ['activation_33[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 33, 48, 32)  96          ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_34 (BatchN  (None, 33, 48, 48)  144         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 33, 48, 32)   0           ['batch_normalization_31[0][0]']
#
#  activation_34 (Activation)     (None, 33, 48, 48)   0           ['batch_normalization_34[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 33, 48, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 33, 48, 32)   9216        ['activation_31[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 33, 48, 64)   27648       ['activation_34[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 33, 48, 32)  96          ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_32 (BatchN  (None, 33, 48, 32)  96          ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_35 (BatchN  (None, 33, 48, 64)  192         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 33, 48, 32)   0           ['batch_normalization_30[0][0]']
#
#  activation_32 (Activation)     (None, 33, 48, 32)   0           ['batch_normalization_32[0][0]']
#
#  activation_35 (Activation)     (None, 33, 48, 64)   0           ['batch_normalization_35[0][0]']
#
#  block35_4_mixed (Concatenate)  (None, 33, 48, 128)  0           ['activation_30[0][0]',
#                                                                   'activation_32[0][0]',
#                                                                   'activation_35[0][0]']
#
#  block35_4_conv (Conv2D)        (None, 33, 48, 320)  41280       ['block35_4_mixed[0][0]']
#
#  block35_4 (Lambda)             (None, 33, 48, 320)  0           ['block35_3_ac[0][0]',
#                                                                   'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)      (None, 33, 48, 320)  0           ['block35_4[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 33, 48, 32)   10240       ['block35_4_ac[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 33, 48, 32)  96          ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 33, 48, 32)   0           ['batch_normalization_39[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 33, 48, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 33, 48, 48)   13824       ['activation_39[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 33, 48, 32)  96          ['conv2d_37[0][0]']
#  ormalization)
#
#  batch_normalization_40 (BatchN  (None, 33, 48, 48)  144         ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 33, 48, 32)   0           ['batch_normalization_37[0][0]']
#
#  activation_40 (Activation)     (None, 33, 48, 48)   0           ['batch_normalization_40[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 33, 48, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 33, 48, 32)   9216        ['activation_37[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 33, 48, 64)   27648       ['activation_40[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 33, 48, 32)  96          ['conv2d_36[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 33, 48, 32)  96          ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_41 (BatchN  (None, 33, 48, 64)  192         ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 33, 48, 32)   0           ['batch_normalization_36[0][0]']
#
#  activation_38 (Activation)     (None, 33, 48, 32)   0           ['batch_normalization_38[0][0]']
#
#  activation_41 (Activation)     (None, 33, 48, 64)   0           ['batch_normalization_41[0][0]']
#
#  block35_5_mixed (Concatenate)  (None, 33, 48, 128)  0           ['activation_36[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_41[0][0]']
#
#  block35_5_conv (Conv2D)        (None, 33, 48, 320)  41280       ['block35_5_mixed[0][0]']
#
#  block35_5 (Lambda)             (None, 33, 48, 320)  0           ['block35_4_ac[0][0]',
#                                                                   'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)      (None, 33, 48, 320)  0           ['block35_5[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 33, 48, 32)   10240       ['block35_5_ac[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 33, 48, 32)  96          ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 33, 48, 32)   0           ['batch_normalization_45[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 33, 48, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 33, 48, 48)   13824       ['activation_45[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 33, 48, 32)  96          ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 33, 48, 48)  144         ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 33, 48, 32)   0           ['batch_normalization_43[0][0]']
#
#  activation_46 (Activation)     (None, 33, 48, 48)   0           ['batch_normalization_46[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 33, 48, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 33, 48, 32)   9216        ['activation_43[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 33, 48, 64)   27648       ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 33, 48, 32)  96          ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_44 (BatchN  (None, 33, 48, 32)  96          ['conv2d_44[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 33, 48, 64)  192         ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 33, 48, 32)   0           ['batch_normalization_42[0][0]']
#
#  activation_44 (Activation)     (None, 33, 48, 32)   0           ['batch_normalization_44[0][0]']
#
#  activation_47 (Activation)     (None, 33, 48, 64)   0           ['batch_normalization_47[0][0]']
#
#  block35_6_mixed (Concatenate)  (None, 33, 48, 128)  0           ['activation_42[0][0]',
#                                                                   'activation_44[0][0]',
#                                                                   'activation_47[0][0]']
#
#  block35_6_conv (Conv2D)        (None, 33, 48, 320)  41280       ['block35_6_mixed[0][0]']
#
#  block35_6 (Lambda)             (None, 33, 48, 320)  0           ['block35_5_ac[0][0]',
#                                                                   'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)      (None, 33, 48, 320)  0           ['block35_6[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 33, 48, 32)   10240       ['block35_6_ac[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 33, 48, 32)  96          ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 33, 48, 32)   0           ['batch_normalization_51[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 33, 48, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 33, 48, 48)   13824       ['activation_51[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 33, 48, 32)  96          ['conv2d_49[0][0]']
#  ormalization)
#
#  batch_normalization_52 (BatchN  (None, 33, 48, 48)  144         ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 33, 48, 32)   0           ['batch_normalization_49[0][0]']
#
#  activation_52 (Activation)     (None, 33, 48, 48)   0           ['batch_normalization_52[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 33, 48, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 33, 48, 32)   9216        ['activation_49[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 33, 48, 64)   27648       ['activation_52[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 33, 48, 32)  96          ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_50 (BatchN  (None, 33, 48, 32)  96          ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 33, 48, 64)  192         ['conv2d_53[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 33, 48, 32)   0           ['batch_normalization_48[0][0]']
#
#  activation_50 (Activation)     (None, 33, 48, 32)   0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 33, 48, 64)   0           ['batch_normalization_53[0][0]']
#
#  block35_7_mixed (Concatenate)  (None, 33, 48, 128)  0           ['activation_48[0][0]',
#                                                                   'activation_50[0][0]',
#                                                                   'activation_53[0][0]']
#
#  block35_7_conv (Conv2D)        (None, 33, 48, 320)  41280       ['block35_7_mixed[0][0]']
#
#  block35_7 (Lambda)             (None, 33, 48, 320)  0           ['block35_6_ac[0][0]',
#                                                                   'block35_7_conv[0][0]']
#
#  block35_7_ac (Activation)      (None, 33, 48, 320)  0           ['block35_7[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 33, 48, 32)   10240       ['block35_7_ac[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 33, 48, 32)  96          ['conv2d_57[0][0]']
# ...
#
#  block8_7 (Lambda)              (None, 7, 11, 2080)  0           ['block8_6_ac[0][0]',
#                                                                   'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)       (None, 7, 11, 2080)  0           ['block8_7[0][0]']
#
#  conv2d_192 (Conv2D)            (None, 7, 11, 192)   399360      ['block8_7_ac[0][0]']
#
#  batch_normalization_192 (Batch  (None, 7, 11, 192)  576         ['conv2d_192[0][0]']
#  Normalization)
#
#  activation_192 (Activation)    (None, 7, 11, 192)   0           ['batch_normalization_192[0][0]']
#
#  conv2d_193 (Conv2D)            (None, 7, 11, 224)   129024      ['activation_192[0][0]']
#
#  batch_normalization_193 (Batch  (None, 7, 11, 224)  672         ['conv2d_193[0][0]']
#  Normalization)
#
#  activation_193 (Activation)    (None, 7, 11, 224)   0           ['batch_normalization_193[0][0]']
#
#  conv2d_191 (Conv2D)            (None, 7, 11, 192)   399360      ['block8_7_ac[0][0]']
#
#  conv2d_194 (Conv2D)            (None, 7, 11, 256)   172032      ['activation_193[0][0]']
#
#  batch_normalization_191 (Batch  (None, 7, 11, 192)  576         ['conv2d_191[0][0]']
#  Normalization)
#
#  batch_normalization_194 (Batch  (None, 7, 11, 256)  768         ['conv2d_194[0][0]']
#  Normalization)
#
#  activation_191 (Activation)    (None, 7, 11, 192)   0           ['batch_normalization_191[0][0]']
#
#  activation_194 (Activation)    (None, 7, 11, 256)   0           ['batch_normalization_194[0][0]']
#
#  block8_8_mixed (Concatenate)   (None, 7, 11, 448)   0           ['activation_191[0][0]',
#                                                                   'activation_194[0][0]']
#
#  block8_8_conv (Conv2D)         (None, 7, 11, 2080)  933920      ['block8_8_mixed[0][0]']
#
#  block8_8 (Lambda)              (None, 7, 11, 2080)  0           ['block8_7_ac[0][0]',
#                                                                   'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)       (None, 7, 11, 2080)  0           ['block8_8[0][0]']
#
#  conv2d_196 (Conv2D)            (None, 7, 11, 192)   399360      ['block8_8_ac[0][0]']
#
#  batch_normalization_196 (Batch  (None, 7, 11, 192)  576         ['conv2d_196[0][0]']
#  Normalization)
#
#  activation_196 (Activation)    (None, 7, 11, 192)   0           ['batch_normalization_196[0][0]']
#
#  conv2d_197 (Conv2D)            (None, 7, 11, 224)   129024      ['activation_196[0][0]']
#
#  batch_normalization_197 (Batch  (None, 7, 11, 224)  672         ['conv2d_197[0][0]']
#  Normalization)
#
#  activation_197 (Activation)    (None, 7, 11, 224)   0           ['batch_normalization_197[0][0]']
#
#  conv2d_195 (Conv2D)            (None, 7, 11, 192)   399360      ['block8_8_ac[0][0]']
#
#  conv2d_198 (Conv2D)            (None, 7, 11, 256)   172032      ['activation_197[0][0]']
#
#  batch_normalization_195 (Batch  (None, 7, 11, 192)  576         ['conv2d_195[0][0]']
#  Normalization)
#
#  batch_normalization_198 (Batch  (None, 7, 11, 256)  768         ['conv2d_198[0][0]']
#  Normalization)
#
#  activation_195 (Activation)    (None, 7, 11, 192)   0           ['batch_normalization_195[0][0]']
#
#  activation_198 (Activation)    (None, 7, 11, 256)   0           ['batch_normalization_198[0][0]']
#
#  block8_9_mixed (Concatenate)   (None, 7, 11, 448)   0           ['activation_195[0][0]',
#                                                                   'activation_198[0][0]']
#
#  block8_9_conv (Conv2D)         (None, 7, 11, 2080)  933920      ['block8_9_mixed[0][0]']
#
#  block8_9 (Lambda)              (None, 7, 11, 2080)  0           ['block8_8_ac[0][0]',
#                                                                   'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)       (None, 7, 11, 2080)  0           ['block8_9[0][0]']
#
#  conv2d_200 (Conv2D)            (None, 7, 11, 192)   399360      ['block8_9_ac[0][0]']
#
#  batch_normalization_200 (Batch  (None, 7, 11, 192)  576         ['conv2d_200[0][0]']
#  Normalization)
#
#  activation_200 (Activation)    (None, 7, 11, 192)   0           ['batch_normalization_200[0][0]']
#
#  conv2d_201 (Conv2D)            (None, 7, 11, 224)   129024      ['activation_200[0][0]']
#
#  batch_normalization_201 (Batch  (None, 7, 11, 224)  672         ['conv2d_201[0][0]']
#  Normalization)
#
#  activation_201 (Activation)    (None, 7, 11, 224)   0           ['batch_normalization_201[0][0]']
#
#  conv2d_199 (Conv2D)            (None, 7, 11, 192)   399360      ['block8_9_ac[0][0]']
#
#  conv2d_202 (Conv2D)            (None, 7, 11, 256)   172032      ['activation_201[0][0]']
#
#  batch_normalization_199 (Batch  (None, 7, 11, 192)  576         ['conv2d_199[0][0]']
#  Normalization)
#
#  batch_normalization_202 (Batch  (None, 7, 11, 256)  768         ['conv2d_202[0][0]']
#  Normalization)
#
#  activation_199 (Activation)    (None, 7, 11, 192)   0           ['batch_normalization_199[0][0]']
#
#  activation_202 (Activation)    (None, 7, 11, 256)   0           ['batch_normalization_202[0][0]']
#
#  block8_10_mixed (Concatenate)  (None, 7, 11, 448)   0           ['activation_199[0][0]',
#                                                                   'activation_202[0][0]']
#
#  block8_10_conv (Conv2D)        (None, 7, 11, 2080)  933920      ['block8_10_mixed[0][0]']
#
#  block8_10 (Lambda)             (None, 7, 11, 2080)  0           ['block8_9_ac[0][0]',
#                                                                   'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)               (None, 7, 11, 1536)  3194880     ['block8_10[0][0]']
#
#  conv_7b_bn (BatchNormalization  (None, 7, 11, 1536)  4608       ['conv_7b[0][0]']
#  )
#
#  conv_7b_ac (Activation)        (None, 7, 11, 1536)  0           ['conv_7b_bn[0][0]']
#
# ==================================================================================================
# Total params: 54,336,736
# Trainable params: 54,276,192
# Non-trainable params: 60,544
# __________________________________________________________________________________________________
# input_shape_model = (288, 409, 3)
# output_shape_model = (7, 11, 1536)
# Applying image transformer to training images...
# Applying image transformer to test images...
#  -> X_train.shape = (848, 288, 409, 3)
#  -> X_test.shape = (140, 288, 409, 3)
# Inferencing embeddings using pre-trained model...
#  -> E_train.shape = (848, 7, 11, 1536)
#  -> E_test.shape = (140, 7, 11, 1536)
#  -> E_train_flatten.shape = (848, 118272)
#  -> E_test_flatten.shape = (140, 118272)
# Fitting k-nearest-neighbour model on training images...
# Performing image retrieval on test images...
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# retrieval accuracy: 1.9814285714285715
# retrieval loss: 0.018571428571428572
# retrieval precision: 1.0
# retrieval recall: 0.9935714285714285

# %% [markdown]
# ## Contoh Output Image Retrieval

# %% [markdown]
# Contoh Output
# ![vgg19_retrieval_1.png](data:image/png;base64,...)
